# %%
import pandas as pd
import numpy as np
import matplotlib
import seaborn as sns
from matplotlib import pyplot as plt

# %%
df = pd.read_csv("dataset.csv")

# %%
df.head()
# Out:
#    Area  Price
# 0   200   10.0
# 1   250   10.5
# 2   300   11.0
# 3   350   11.5
# 4   400   12.0

# %%
x = df.Area
y = df.Price

# %%
x
# Out:
# 0        200
# 1        250
# 2        300
# 3        350
# 4        400
#        ...
# 193     9850
# 194     9900
# 195     9950
# 196    10000
# 197    10050
# Name: Area, Length: 198, dtype: int64

# %%
y
# Out:
# 0       10.0
# 1       10.5
# 2       11.0
# 3       11.5
# 4       12.0
#        ...
# 193    106.5
# 194    107.0
# 195    107.5
# 196    108.0
# 197    108.5
# Name: Price, Length: 198, dtype: float64

# %%
plt.plot(x,y)
plt.xlabel("Area")
plt.ylabel("Price")
plt.title("Area and price")
plt.show()

# %%
sns.pairplot(df,x_vars='Area',y_vars ='Price',kind ='scatter',diag_kind = None)

# %%
x
# Out:
# 0        200
# 1        250
# 2        300
# 3        350
# 4        400
#        ...
# 193     9850
# 194     9900
# 195     9950
# 196    10000
# 197    10050
# Name: Area, Length: 198, dtype: int64

# %%
y
# Out:
# 0       10.0
# 1       10.5
# 2       11.0
# 3       11.5
# 4       12.0
#        ...
# 193    106.5
# 194    107.0
# 195    107.5
# 196    108.0
# 197    108.5
# Name: Price, Length: 198, dtype: float64

# %%
X = np.array(x).reshape(-1,1)

# %%
X
# Out:
# array([[  200],
#        [  250],
#        [  300],
#        [  350],
#        [  400],
#        [  450],
#        [  500],
#        [  550],
#        [  600],
#        [  650],
#        [  700],
#        [  750],
#        [  800],
#        [  850],
#        [  900],
#        [  950],
#        [ 1000],
#        [ 1050],
#        [ 1100],
#        [ 1150],
#        [ 1200],
#        [ 1250],
#        [ 1300],
#        [ 1350],
#        [ 1400],
#        [ 1450],
#        [ 1500],
#        [ 1550],
#        [ 1600],
#        [ 1650],
#        [ 1700],
#        [ 1750],
#        [ 1800],
#        [ 1850],
#        [ 1900],
#        [ 1950],
#        [ 2000],
#        [ 2050],
#        [ 2100],
#        [ 2150],
#        [ 2200],
#        [ 2250],
#        [ 2300],
#        [ 2350],
#        [ 2400],
#        [ 2450],
#        [ 2500],
#        [ 2550],
#        [ 2600],
#        [ 2650],
#        [ 2700],
#        [ 2750],
#        [ 2800],
#        [ 2850],
#        [ 2900],
# ...

# %%
Y = np.array(y).reshape(-1,1)

# %%
Y
# Out:
# array([[ 10. ],
#        [ 10.5],
#        [ 11. ],
#        [ 11.5],
#        [ 12. ],
#        [ 12.5],
#        [ 13. ],
#        [ 13.5],
#        [ 14. ],
#        [ 14.5],
#        [ 15. ],
#        [ 15.5],
#        [ 16. ],
#        [ 16.5],
#        [ 17. ],
#        [ 17.5],
#        [ 18. ],
#        [ 18.5],
#        [ 19. ],
#        [ 19.5],
#        [ 20. ],
#        [ 20.5],
#        [ 21. ],
#        [ 21.5],
#        [ 22. ],
#        [ 22.5],
#        [ 23. ],
#        [ 23.5],
#        [ 24. ],
#        [ 24.5],
#        [ 25. ],
#        [ 25.5],
#        [ 26. ],
#        [ 26.5],
#        [ 27. ],
#        [ 27.5],
#        [ 28. ],
#        [ 28.5],
#        [ 29. ],
#        [ 29.5],
#        [ 30. ],
#        [ 30.5],
#        [ 31. ],
#        [ 31.5],
#        [ 32. ],
#        [ 32.5],
#        [ 33. ],
#        [ 33.5],
#        [ 34. ],
#        [ 34.5],
#        [ 35. ],
#        [ 35.5],
#        [ 36. ],
#        [ 36.5],
#        [ 37. ],
# ...

# %%
import sklearn
from sklearn.model_selection import train_test_split

# %%
x_train, x_test,y_train,y_test  = train_test_split(X,Y,random_state = 0,train_size =0.70)

# %%
x_train
# Out:
# array([[ 7150],
#        [ 4200],
#        [ 1150],
#        [ 8150],
#        [ 4700],
#        [ 2900],
#        [ 8250],
#        [ 2750],
#        [ 6700],
#        [ 7050],
#        [ 9200],
#        [ 4650],
#        [ 6450],
#        [ 9100],
#        [ 9300],
#        [ 5550],
#        [  900],
#        [ 1550],
#        [ 6300],
#        [ 9950],
#        [ 2500],
#        [ 9850],
#        [ 5500],
#        [ 3300],
#        [  300],
#        [ 3150],
#        [ 8100],
#        [10050],
#        [ 2350],
#        [  700],
#        [ 5250],
#        [ 3850],
#        [ 9700],
#        [ 9000],
#        [ 7500],
#        [ 6400],
#        [ 4850],
#        [ 5700],
#        [ 8000],
#        [ 9650],
#        [ 2700],
#        [  200],
#        [ 4900],
#        [ 5600],
#        [ 4950],
#        [ 3400],
#        [ 9450],
#        [ 2250],
#        [ 3650],
#        [ 2650],
#        [ 2600],
#        [ 4450],
#        [  850],
#        [ 7650],
#        [ 1350],
# ...

# %%
y_train
# Out:
# array([[ 79.5],
#        [ 50. ],
#        [ 19.5],
#        [ 89.5],
#        [ 55. ],
#        [ 37. ],
#        [ 90.5],
#        [ 35.5],
#        [ 75. ],
#        [ 78.5],
#        [100. ],
#        [ 54.5],
#        [ 72.5],
#        [ 99. ],
#        [101. ],
#        [ 63.5],
#        [ 17. ],
#        [ 23.5],
#        [ 71. ],
#        [107.5],
#        [ 33. ],
#        [106.5],
#        [ 63. ],
#        [ 41. ],
#        [ 11. ],
#        [ 39.5],
#        [ 89. ],
#        [108.5],
#        [ 31.5],
#        [ 15. ],
#        [ 60.5],
#        [ 46.5],
#        [105. ],
#        [ 98. ],
#        [ 83. ],
#        [ 72. ],
#        [ 56.5],
#        [ 65. ],
#        [ 88. ],
#        [104.5],
#        [ 35. ],
#        [ 10. ],
#        [ 57. ],
#        [ 64. ],
#        [ 57.5],
#        [ 42. ],
#        [102.5],
#        [ 30.5],
#        [ 44.5],
#        [ 34.5],
#        [ 34. ],
#        [ 52.5],
#        [ 16.5],
#        [ 84.5],
#        [ 21.5],
# ...

# %%
x_test
# Out:
# array([[1100],
#        [8600],
#        [3350],
#        [8950],
#        [3750],
#        [4500],
#        [ 450],
#        [6100],
#        [ 800],
#        [7700],
#        [3200],
#        [3950],
#        [8350],
#        [5000],
#        [5850],
#        [ 550],
#        [1850],
#        [6900],
#        [2050],
#        [8500],
#        [5650],
#        [7350],
#        [2450],
#        [8050],
#        [7100],
#        [5750],
#        [9050],
#        [9350],
#        [4800],
#        [2400],
#        [1000],
#        [6950],
#        [7000],
#        [5050],
#        [1300],
#        [9900],
#        [6500],
#        [ 400],
#        [3500],
#        [6350],
#        [6750],
#        [8850],
#        [1500],
#        [3250],
#        [7450],
#        [4350],
#        [ 600],
#        [7250],
#        [3900],
#        [9550],
#        [5100],
#        [2950],
#        [7400],
#        [8300],
#        [1400],
#        [1700],
#        [5800],
#        [2200],
# ...

# %%
from sklearn import linear_model

# %%
from sklearn.linear_model import LinearRegression

# %%
model = LinearRegression()

# %%
model.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
y_pred = model.predict(x_test)

# %%
y_pred
# Out:
# array([[ 19. ],
#        [ 94. ],
#        [ 41.5],
#        [ 97.5],
#        [ 45.5],
#        [ 53. ],
#        [ 12.5],
#        [ 69. ],
#        [ 16. ],
#        [ 85. ],
#        [ 40. ],
#        [ 47.5],
#        [ 91.5],
#        [ 58. ],
#        [ 66.5],
#        [ 13.5],
#        [ 26.5],
#        [ 77. ],
#        [ 28.5],
#        [ 93. ],
#        [ 64.5],
#        [ 81.5],
#        [ 32.5],
#        [ 88.5],
#        [ 79. ],
#        [ 65.5],
#        [ 98.5],
#        [101.5],
#        [ 56. ],
#        [ 32. ],
#        [ 18. ],
#        [ 77.5],
#        [ 78. ],
#        [ 58.5],
#        [ 21. ],
#        [107. ],
#        [ 73. ],
#        [ 12. ],
#        [ 43. ],
#        [ 71.5],
#        [ 75.5],
#        [ 96.5],
#        [ 23. ],
#        [ 40.5],
#        [ 82.5],
#        [ 51.5],
#        [ 14. ],
#        [ 80.5],
#        [ 47. ],
#        [103.5],
#        [ 59. ],
#        [ 37.5],
#        [ 82. ],
#        [ 91. ],
#        [ 22. ],
# ...

# %%
x_test
# Out:
# array([[1100],
#        [8600],
#        [3350],
#        [8950],
#        [3750],
#        [4500],
#        [ 450],
#        [6100],
#        [ 800],
#        [7700],
#        [3200],
#        [3950],
#        [8350],
#        [5000],
#        [5850],
#        [ 550],
#        [1850],
#        [6900],
#        [2050],
#        [8500],
#        [5650],
#        [7350],
#        [2450],
#        [8050],
#        [7100],
#        [5750],
#        [9050],
#        [9350],
#        [4800],
#        [2400],
#        [1000],
#        [6950],
#        [7000],
#        [5050],
#        [1300],
#        [9900],
#        [6500],
#        [ 400],
#        [3500],
#        [6350],
#        [6750],
#        [8850],
#        [1500],
#        [3250],
#        [7450],
#        [4350],
#        [ 600],
#        [7250],
#        [3900],
#        [9550],
#        [5100],
#        [2950],
#        [7400],
#        [8300],
#        [1400],
#        [1700],
#        [5800],
#        [2200],
# ...

# %%
from sklearn.metrics import mean_squared_error

# %%
mse = mean_squared_error(y_test,y_pred)

# %%
mse
# Out:
# 9.255967954593205e-30

# %%
from sklearn.metrics import mean_absolute_error
mae = mean_absolute_error(y_test,y_pred)

# %%
mae
# Out:
# 1.4210854715202005e-15

# %%
from sklearn.metrics import mean_absolute_percentage_error

# %%
map_error = mean_absolute_percentage_error(y_test,y_pred)

# %%
map_error
# Out:
# 8.161215917896343e-17

# %%
final_accuracy = 100 - map_error

# %%
final_accuracy
# Out:
# 100.0

# %%
rsme = (mse)^(0.5)
rsme
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[52], line 1
# ----> 1 rsme = (mse)^(0.5)
#       2 rsme
#
# TypeError: ufunc 'bitwise_xor' not supported for the input types, and the inputs could not be safely coerced to any supported types according to the casting rule ''safe''
